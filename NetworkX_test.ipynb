# %%
import networkx as nx
G = nx.Graph()
G.add_node(1)
G.add_nodes_from([2, 3, 4])
nx.draw_networkx(G)

# %%
import matplotlib.pyplot as ptl

G = nx.complete_graph(20)
nx.draw_networkx(G)

# %%
nx.draw_circular(G)
